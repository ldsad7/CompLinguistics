# %%
import nltk
import re
import pandas as pd
import numpy as np

# %%
sents = ['Вася читает мою книгу', 'Напиши какое-нибудь письмо', 'Этот веселый мальчик идет', 'Он любит читать всякие книги']

# %%
rules = """
    S -> NP VP | NP V | VP
    NP -> ADJ N | ADJ NP
    VP -> V NP | V VP | V N
    ADJ -> 'мою' | 'какое-нибудь' | 'Этот' | 'веселый' | 'всякие'
    N -> 'книгу' | 'письмо' | 'мальчик' | 'книги'
    NP -> 'Вася' | 'Он'
    V -> 'читает' | 'Напиши' | 'идет' | 'любит' | 'читать'
""".split('\n')

# %%
grammar = nltk.CFG.fromstring('\n'.join(rules))

# %%
def print_parses(parser, sentence):
    for elem in parser.parse(sentence.split()):
        print(elem)

# %% [markdown]
# ### Продемонстрируем алгоритм CYK parser-а

# %% [markdown]
# Матрица в CYK должна быть трёхмерной, но ради удобства сделаем её двумерной, схлопнув по оси Z.

# %%
n = 4
sent = sents[0].split()
df = pd.DataFrame(np.empty((n + 1, n)), columns=range(1, n + 1), dtype=str)
df = df.reindex(index=df.index[::-1])
df[:] = ''

# %% [markdown]
# #### На нулевую строку поместим слова нашего предложения

# %%
df.iloc[n, :] = sent
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_d8908e6c_2977_11e9_a11e_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row3_col3 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row4_col0 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row4_col1 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row4_col2 {
#             text-align:  center;
#         }    #T_d8908e6c_2977_11e9_a11e_44032cd22778row4_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_d8908e6c_2977_11e9_a11e_44032cd22778" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d8908e6c_2977_11e9_a11e_44032cd22778level0_row0" class="row_heading level0 row0" >4</th>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row0_col0" class="data row0 col0" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row0_col1" class="data row0 col1" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row0_col2" class="data row0 col2" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row0_col3" class="data row0 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8908e6c_2977_11e9_a11e_44032cd22778level0_row1" class="row_heading level0 row1" >3</th>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row1_col0" class="data row1 col0" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row1_col1" class="data row1 col1" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row1_col2" class="data row1 col2" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row1_col3" class="data row1 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8908e6c_2977_11e9_a11e_44032cd22778level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row2_col0" class="data row2 col0" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row2_col1" class="data row2 col1" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row2_col2" class="data row2 col2" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row2_col3" class="data row2 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8908e6c_2977_11e9_a11e_44032cd22778level0_row3" class="row_heading level0 row3" >1</th>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row3_col0" class="data row3 col0" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row3_col1" class="data row3 col1" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row3_col2" class="data row3 col2" ></td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row3_col3" class="data row3 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8908e6c_2977_11e9_a11e_44032cd22778level0_row4" class="row_heading level0 row4" >0</th>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row4_col0" class="data row4 col0" >Вася</td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row4_col1" class="data row4 col1" >читает</td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row4_col2" class="data row4 col2" >мою</td>
#         <td id="T_d8908e6c_2977_11e9_a11e_44032cd22778row4_col3" class="data row4 col3" >книгу</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# #### Заполним первый ряд в соответствии с алгоритмом, т.е. пройдёмся с шагом 1 по первому ряду и запишем все возможные нетерминальные вершины, которые переходят в соответствующие терминальные

# %%
df.iloc[n - 1, :] = np.array(('NP', 'V', 'ADJ', 'N'))
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_d895c75c_2977_11e9_9348_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row3_col3 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row4_col0 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row4_col1 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row4_col2 {
#             text-align:  center;
#         }    #T_d895c75c_2977_11e9_9348_44032cd22778row4_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_d895c75c_2977_11e9_9348_44032cd22778" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d895c75c_2977_11e9_9348_44032cd22778level0_row0" class="row_heading level0 row0" >4</th>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row0_col0" class="data row0 col0" ></td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row0_col1" class="data row0 col1" ></td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row0_col2" class="data row0 col2" ></td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row0_col3" class="data row0 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d895c75c_2977_11e9_9348_44032cd22778level0_row1" class="row_heading level0 row1" >3</th>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row1_col0" class="data row1 col0" ></td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row1_col1" class="data row1 col1" ></td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row1_col2" class="data row1 col2" ></td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row1_col3" class="data row1 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d895c75c_2977_11e9_9348_44032cd22778level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row2_col0" class="data row2 col0" ></td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row2_col1" class="data row2 col1" ></td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row2_col2" class="data row2 col2" ></td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row2_col3" class="data row2 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d895c75c_2977_11e9_9348_44032cd22778level0_row3" class="row_heading level0 row3" >1</th>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row3_col0" class="data row3 col0" >NP</td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row3_col1" class="data row3 col1" >V</td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row3_col2" class="data row3 col2" >ADJ</td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row3_col3" class="data row3 col3" >N</td>
#     </tr>    <tr>
#         <th id="T_d895c75c_2977_11e9_9348_44032cd22778level0_row4" class="row_heading level0 row4" >0</th>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row4_col0" class="data row4 col0" >Вася</td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row4_col1" class="data row4 col1" >читает</td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row4_col2" class="data row4 col2" >мою</td>
#         <td id="T_d895c75c_2977_11e9_9348_44032cd22778row4_col3" class="data row4 col3" >книгу</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# #### Заполним второй ряд в соответствии с алгоритмом, т.е. пройдёмся с шагом 2 по второму ряду и найдём все возможные разбиения на 2 составляющих, поскольку мы исходим из предположения о том, что грамматика в нормальной форме Хомского. В данном случае нашли только одно разложение: NP -> Adj N

# %%
df.iloc[n - 2, :] = np.array(('', '', 'NP', ''))
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_d8b100c2_2977_11e9_beb0_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row3_col3 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row4_col0 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row4_col1 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row4_col2 {
#             text-align:  center;
#         }    #T_d8b100c2_2977_11e9_beb0_44032cd22778row4_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_d8b100c2_2977_11e9_beb0_44032cd22778" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d8b100c2_2977_11e9_beb0_44032cd22778level0_row0" class="row_heading level0 row0" >4</th>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row0_col0" class="data row0 col0" ></td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row0_col1" class="data row0 col1" ></td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row0_col2" class="data row0 col2" ></td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row0_col3" class="data row0 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8b100c2_2977_11e9_beb0_44032cd22778level0_row1" class="row_heading level0 row1" >3</th>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row1_col0" class="data row1 col0" ></td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row1_col1" class="data row1 col1" ></td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row1_col2" class="data row1 col2" ></td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row1_col3" class="data row1 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8b100c2_2977_11e9_beb0_44032cd22778level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row2_col0" class="data row2 col0" ></td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row2_col1" class="data row2 col1" ></td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row2_col2" class="data row2 col2" >NP</td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row2_col3" class="data row2 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8b100c2_2977_11e9_beb0_44032cd22778level0_row3" class="row_heading level0 row3" >1</th>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row3_col0" class="data row3 col0" >NP</td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row3_col1" class="data row3 col1" >V</td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row3_col2" class="data row3 col2" >ADJ</td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row3_col3" class="data row3 col3" >N</td>
#     </tr>    <tr>
#         <th id="T_d8b100c2_2977_11e9_beb0_44032cd22778level0_row4" class="row_heading level0 row4" >0</th>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row4_col0" class="data row4 col0" >Вася</td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row4_col1" class="data row4 col1" >читает</td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row4_col2" class="data row4 col2" >мою</td>
#         <td id="T_d8b100c2_2977_11e9_beb0_44032cd22778row4_col3" class="data row4 col3" >книгу</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# #### Заполним третий ряд в соответствии с алгоритмом, т.е. пройдёмся с шагом 3 по третьему ряду и найдём все возможные разбиения на 2 составляющих, поскольку мы исходим из предположения о то, что грамматика в нормальной форме Хомского. В данном случае нашли только одно разложение VP -> V NP

# %%
df.iloc[n - 3, :] = np.array(('', 'VP', '', ''))
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_d8ebe842_2977_11e9_adf1_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row3_col3 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row4_col0 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row4_col1 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row4_col2 {
#             text-align:  center;
#         }    #T_d8ebe842_2977_11e9_adf1_44032cd22778row4_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_d8ebe842_2977_11e9_adf1_44032cd22778" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d8ebe842_2977_11e9_adf1_44032cd22778level0_row0" class="row_heading level0 row0" >4</th>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row0_col0" class="data row0 col0" ></td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row0_col1" class="data row0 col1" ></td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row0_col2" class="data row0 col2" ></td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row0_col3" class="data row0 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8ebe842_2977_11e9_adf1_44032cd22778level0_row1" class="row_heading level0 row1" >3</th>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row1_col0" class="data row1 col0" ></td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row1_col1" class="data row1 col1" >VP</td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row1_col2" class="data row1 col2" ></td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row1_col3" class="data row1 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8ebe842_2977_11e9_adf1_44032cd22778level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row2_col0" class="data row2 col0" ></td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row2_col1" class="data row2 col1" ></td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row2_col2" class="data row2 col2" >NP</td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row2_col3" class="data row2 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d8ebe842_2977_11e9_adf1_44032cd22778level0_row3" class="row_heading level0 row3" >1</th>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row3_col0" class="data row3 col0" >NP</td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row3_col1" class="data row3 col1" >V</td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row3_col2" class="data row3 col2" >ADJ</td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row3_col3" class="data row3 col3" >N</td>
#     </tr>    <tr>
#         <th id="T_d8ebe842_2977_11e9_adf1_44032cd22778level0_row4" class="row_heading level0 row4" >0</th>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row4_col0" class="data row4 col0" >Вася</td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row4_col1" class="data row4 col1" >читает</td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row4_col2" class="data row4 col2" >мою</td>
#         <td id="T_d8ebe842_2977_11e9_adf1_44032cd22778row4_col3" class="data row4 col3" >книгу</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# #### Наконец, проверим, что S правильно раскладывается и на последнем ряду. И действительно, S -> NP VP

# %%
df.iloc[n - 4, :] = np.array(('S', '', '', ''))
df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_d925c4c8_2977_11e9_a838_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row3_col3 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row4_col0 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row4_col1 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row4_col2 {
#             text-align:  center;
#         }    #T_d925c4c8_2977_11e9_a838_44032cd22778row4_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_d925c4c8_2977_11e9_a838_44032cd22778" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >4</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d925c4c8_2977_11e9_a838_44032cd22778level0_row0" class="row_heading level0 row0" >4</th>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row0_col0" class="data row0 col0" >S</td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row0_col1" class="data row0 col1" ></td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row0_col2" class="data row0 col2" ></td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row0_col3" class="data row0 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d925c4c8_2977_11e9_a838_44032cd22778level0_row1" class="row_heading level0 row1" >3</th>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row1_col0" class="data row1 col0" ></td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row1_col1" class="data row1 col1" >VP</td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row1_col2" class="data row1 col2" ></td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row1_col3" class="data row1 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d925c4c8_2977_11e9_a838_44032cd22778level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row2_col0" class="data row2 col0" ></td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row2_col1" class="data row2 col1" ></td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row2_col2" class="data row2 col2" >NP</td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row2_col3" class="data row2 col3" ></td>
#     </tr>    <tr>
#         <th id="T_d925c4c8_2977_11e9_a838_44032cd22778level0_row3" class="row_heading level0 row3" >1</th>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row3_col0" class="data row3 col0" >NP</td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row3_col1" class="data row3 col1" >V</td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row3_col2" class="data row3 col2" >ADJ</td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row3_col3" class="data row3 col3" >N</td>
#     </tr>    <tr>
#         <th id="T_d925c4c8_2977_11e9_a838_44032cd22778level0_row4" class="row_heading level0 row4" >0</th>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row4_col0" class="data row4 col0" >Вася</td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row4_col1" class="data row4 col1" >читает</td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row4_col2" class="data row4 col2" >мою</td>
#         <td id="T_d925c4c8_2977_11e9_a838_44032cd22778row4_col3" class="data row4 col3" >книгу</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# #### Поскольку в левой верхней ячейке S (True), то это предложение действительно порождается нашей грамматикой

# %% [markdown]
# ### Теперь продемонстрируем алгоритм Earley	parser-а

# %% [markdown]
# #### При добавлении items не учитываем дубликаты, чтобы избежать бесконечного цикла

# %% [markdown]
# #### S(0): • Вася читает мою книгу

# %%
n = 4
m = 20
df = pd.DataFrame(np.empty((m, n)), columns=['(state no.)', 'Production', '(Origin)', 'Comment'], dtype=str)
df[:] = ''
i = 0
df.iloc[i, :] = np.array((i + 1, 'S -> • NP VP', '0', 'start rule'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'S -> • NP V', '0', 'start rule'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'S -> • VP', '0', 'start rule'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'NP -> • ADJ N', '0', 'predict from (1)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'NP -> • ADJ NP', '0', 'predict from (1)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "NP -> • 'Вася'", '0', 'predict from (1)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "NP -> • 'Он'", '0', 'predict from (1)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> • V NP", '0', 'predict from (1)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> • V VP", '0', 'predict from (1)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> • V N", '0', 'predict from (1)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'читает'", '0', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'Напиши'", '0', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'идет'", '0', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'любит'", '0', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'читать'", '0', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'мою'", '0', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'какое-нибудь'", '0', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'Этот'", '0', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'веселый'", '0', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'всякие'", '0', 'predict from (4)'))
"""
# Поскольку в ашей грамматике N никогда не может идти слева, опустим следующие items S(0)
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'книгу'", '0', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'письмо'", '0', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'мальчик'", '0', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'книги'", '0', 'predict from (4)'))
"""

df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_d9b848c2_2977_11e9_a25f_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row3_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row4_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row4_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row4_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row4_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row5_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row5_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row5_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row5_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row6_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row6_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row6_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row6_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row7_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row7_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row7_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row7_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row8_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row8_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row8_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row8_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row9_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row9_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row9_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row9_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row10_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row10_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row10_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row10_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row11_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row11_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row11_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row11_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row12_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row12_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row12_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row12_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row13_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row13_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row13_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row13_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row14_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row14_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row14_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row14_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row15_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row15_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row15_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row15_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row16_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row16_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row16_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row16_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row17_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row17_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row17_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row17_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row18_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row18_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row18_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row18_col3 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row19_col0 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row19_col1 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row19_col2 {
#             text-align:  center;
#         }    #T_d9b848c2_2977_11e9_a25f_44032cd22778row19_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_d9b848c2_2977_11e9_a25f_44032cd22778" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >(state

# %% [markdown]
# #### S(1): Вася • читает мою книгу

# %%
n = 4
m = 11
df = pd.DataFrame(np.empty((m, n)), columns=['(state no.)', 'Production', '(Origin)', 'Comment'], dtype=str)
df[:] = ''
i = 0
df.iloc[i, :] = np.array((i + 1, "NP -> 'Вася' •", '0', 'scan from S(0)(6)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'S -> NP • VP', '0', 'complete from (1) and S(0)(1)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'S -> NP • V', '0', 'complete from (1) and S(0)(2)'))
"""
Больше нет items из S(0), в которых NP было бы слева
"""
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> • V NP", '1', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> • V VP", '1', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> • V N", '1', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'читает'", '1', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'Напиши'", '1', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'идет'", '1', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'любит'", '1', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'читать'", '1', 'predict from (3)'))

df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row3_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row4_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row4_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row4_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row4_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row5_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row5_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row5_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row5_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row6_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row6_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row6_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row6_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row7_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row7_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row7_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row7_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row8_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row8_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row8_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row8_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row9_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row9_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row9_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row9_col3 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row10_col0 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row10_col1 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row10_col2 {
#             text-align:  center;
#         }    #T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row10_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >(state no.)</th>
#         <th class="col_heading level0 col1" >Production</th>
#         <th class="col_heading level0 col2" >(Origin)</th>
#         <th class="col_heading level0 col3" >Comment</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row0_col0" class="data row0 col0" >1</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row0_col1" class="data row0 col1" >NP -> 'Вася' •</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row0_col2" class="data row0 col2" >0</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row0_col3" class="data row0 col3" >scan from S(0)(6)</td>
#     </tr>    <tr>
#         <th id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row1_col0" class="data row1 col0" >2</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row1_col1" class="data row1 col1" >S -> NP • VP</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row1_col2" class="data row1 col2" >0</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row1_col3" class="data row1 col3" >complete from (1) and S(0)(1)</td>
#     </tr>    <tr>
#         <th id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row2_col0" class="data row2 col0" >3</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row2_col1" class="data row2 col1" >S -> NP • V</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row2_col2" class="data row2 col2" >0</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row2_col3" class="data row2 col3" >complete from (1) and S(0)(2)</td>
#     </tr>    <tr>
#         <th id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row3_col0" class="data row3 col0" >4</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row3_col1" class="data row3 col1" >VP -> • V NP</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row3_col2" class="data row3 col2" >1</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row3_col3" class="data row3 col3" >predict from (2)</td>
#     </tr>    <tr>
#         <th id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row4_col0" class="data row4 col0" >5</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row4_col1" class="data row4 col1" >VP -> • V VP</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row4_col2" class="data row4 col2" >1</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row4_col3" class="data row4 col3" >predict from (2)</td>
#     </tr>    <tr>
#         <th id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row5_col0" class="data row5 col0" >6</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row5_col1" class="data row5 col1" >VP -> • V N</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row5_col2" class="data row5 col2" >1</td>
#         <td id="T_d9f2e4a6_2977_11e9_a1d0_44032cd22778row5_col3" class="data row5 col3" >predict from (2)</td>
#     </tr>    <tr>
#         <th id="T_d9f2e4a6

# %% [markdown]
# #### S(2) = Вася читает • мою книгу

# %%
n = 4
m = 26
df = pd.DataFrame(np.empty((m, n)), columns=['(state no.)', 'Production', '(Origin)', 'Comment'], dtype=str)
df[:] = ''
i = 0
df.iloc[i, :] = np.array((i + 1, "V -> 'читает' •", '1', 'scan from S(1)(7)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "S -> NP V •", '0', 'complete from (1) and S(0)(2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> V • NP", '1', 'complete from (1) and S(1)(4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> V • VP", '1', 'complete from (1) and S(1)(5)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> V • N", '1', 'complete from (1) and S(1)(6)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'NP -> • ADJ N', '2', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'NP -> • ADJ NP', '2', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "NP -> • 'Вася'", '2', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "NP -> • 'Он'", '2', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> • V NP", '2', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> • V VP", '2', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> • V N", '2', 'predict from (4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'книгу'", '2', 'predict from (5)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'письмо'", '2', 'predict from (5)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'мальчик'", '2', 'predict from (5)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'книги'", '2', 'predict from (5)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'мою'", '2', 'predict from (6)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'какое-нибудь'", '2', 'predict from (6)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'Этот'", '2', 'predict from (6)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'веселый'", '2', 'predict from (6)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'всякие'", '2', 'predict from (6)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'читает'", '2', 'predict from (10)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'Напиши'", '2', 'predict from (10)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'идет'", '2', 'predict from (10)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'любит'", '2', 'predict from (10)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "V -> • 'читать'", '2', 'predict from (10)'))

df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_da3b7d68_2977_11e9_ba67_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row3_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row4_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row4_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row4_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row4_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row5_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row5_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row5_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row5_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row6_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row6_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row6_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row6_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row7_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row7_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row7_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row7_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row8_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row8_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row8_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row8_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row9_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row9_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row9_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row9_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row10_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row10_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row10_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row10_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row11_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row11_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row11_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row11_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row12_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row12_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row12_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row12_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row13_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row13_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row13_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row13_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row14_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row14_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row14_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row14_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row15_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row15_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row15_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row15_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row16_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row16_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row16_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row16_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row17_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row17_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row17_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row17_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row18_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row18_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row18_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row18_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row19_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row19_col1 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row19_col2 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row19_col3 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row20_col0 {
#             text-align:  center;
#         }    #T_da3b7d68_2977_11e9_ba67_44032cd22778row20_col1 {
#             text-ali

# %% [markdown]
# #### S(3) = Вася читает мою • книгу

# %%
n = 4
m = 16
df = pd.DataFrame(np.empty((m, n)), columns=['(state no.)', 'Production', '(Origin)', 'Comment'], dtype=str)
df[:] = ''
i = 0
df.iloc[i, :] = np.array((i + 1, "ADJ -> 'мою' •", '2', 'scan from S(2)(17)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'NP -> ADJ • N', '2', 'complete from (1) and S(2)(6)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'NP -> ADJ • NP', '2', 'complete from (1) and S(2)(7)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'книгу'", '3', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'письмо'", '3', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'мальчик'", '3', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "N -> • 'книги'", '3', 'predict from (2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'NP -> • ADJ N', '3', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'NP -> • ADJ NP', '3', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "NP -> • 'Вася'", '3', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "NP -> • 'Он'", '3', 'predict from (3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'мою'", '3', 'predict from (8)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'какое-нибудь'", '3', 'predict from (8)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'Этот'", '3', 'predict from (8)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'веселый'", '3', 'predict from (8)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "ADJ -> • 'всякие'", '3', 'predict from (8)'))

df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_da773812_2977_11e9_85a6_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row3_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row4_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row4_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row4_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row4_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row5_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row5_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row5_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row5_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row6_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row6_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row6_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row6_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row7_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row7_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row7_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row7_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row8_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row8_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row8_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row8_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row9_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row9_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row9_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row9_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row10_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row10_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row10_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row10_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row11_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row11_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row11_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row11_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row12_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row12_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row12_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row12_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row13_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row13_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row13_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row13_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row14_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row14_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row14_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row14_col3 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row15_col0 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row15_col1 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row15_col2 {
#             text-align:  center;
#         }    #T_da773812_2977_11e9_85a6_44032cd22778row15_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_da773812_2977_11e9_85a6_44032cd22778" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >(state no.)</th>
#         <th class="col_heading level0 col1" >Production</th>
#         <th class="col_heading level0 col2" >(Origin)</th>
#         <th class="col_heading level0 col3" >Comment</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_da773812_2977_11e9_85a6_44032cd22778level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_da773812_2977_11e9_85a6_44032cd22778row0_col0" class="data row0 col0" >1</td>
#         <td id="T_da773812_2977_11e9_85a6_44032cd22778row0_col1" class="data row0 col1" >ADJ -> 'мою' •</td>
#         <td id="T_da773812_2977_11e9_85a6_44032cd22778row0_col2" class="data row0 col2" >2</td>
#         <td id="T_da773812_2977_11e9_85a6_44032cd22778row0_col3" class="data row0 col3" >scan from S(2)(17)</td>
#     </tr>    <tr>
#         <th id="T_da773812_2977_11e9_85a6_44032cd22778level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_da773812_2977_11e9_85a6_44032cd22778row1_col0" class="data row1 col0" >2</td>
#         <td id="T_da773812_2977_11e9_85a6_44032cd22778row1_col1" class="data row1 col1" >NP -> ADJ • N</td>
#         <td id="T_da773812_2977_11e9_85a6_44032cd22778row1_col2" class="data row1 col2" >2</td>
#         <td id="T_da773812_2977_11e9_85a6_44032cd22778row1_col3" class="data row1 col3" >complete from (1) and S(2)(6)</td>
#     </tr>    <tr>
#         <th id="T_da773812_2977_11e9_85a6_44032cd22778level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_da773812_2977_11e9_85a6_44032cd22778row2_col0" class="data row2 col0" >3</td>
#         <td id="T_da773812_2977_11

# %% [markdown]
# #### S(4) = Вася читает мою книгу •

# %%
n = 4
m = 4
df = pd.DataFrame(np.empty((m, n)), columns=['(state no.)', 'Production', '(Origin)', 'Comment'], dtype=str)
df[:] = ''
i = 0
df.iloc[i, :] = np.array((i + 1, "N -> 'книгу' •", '3', 'scan from S(3)(4)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'NP -> ADJ N •', '2', 'complete from (1) and S(3)(2)'))
i += 1
df.iloc[i, :] = np.array((i + 1, "VP -> V NP •", '1', 'complete from (2) and S(2)(3)'))
i += 1
df.iloc[i, :] = np.array((i + 1, 'S -> NP VP •', '0', 'complete from (3) and S(1)(2)'))

df.style.set_properties(**{'text-align': 'center'})
# Out:
# <style  type="text/css" >
#     #T_dab0c6f8_2977_11e9_bb69_44032cd22778row0_col0 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row0_col1 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row0_col2 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row0_col3 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row1_col0 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row1_col1 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row1_col2 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row1_col3 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row2_col0 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row2_col1 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row2_col2 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row2_col3 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row3_col0 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row3_col1 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row3_col2 {
#             text-align:  center;
#         }    #T_dab0c6f8_2977_11e9_bb69_44032cd22778row3_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_dab0c6f8_2977_11e9_bb69_44032cd22778" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >(state no.)</th>
#         <th class="col_heading level0 col1" >Production</th>
#         <th class="col_heading level0 col2" >(Origin)</th>
#         <th class="col_heading level0 col3" >Comment</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_dab0c6f8_2977_11e9_bb69_44032cd22778level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row0_col0" class="data row0 col0" >1</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row0_col1" class="data row0 col1" >N -> 'книгу' •</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row0_col2" class="data row0 col2" >3</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row0_col3" class="data row0 col3" >scan from S(3)(4)</td>
#     </tr>    <tr>
#         <th id="T_dab0c6f8_2977_11e9_bb69_44032cd22778level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row1_col0" class="data row1 col0" >2</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row1_col1" class="data row1 col1" >NP -> ADJ N •</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row1_col2" class="data row1 col2" >2</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row1_col3" class="data row1 col3" >complete from (1) and S(3)(2)</td>
#     </tr>    <tr>
#         <th id="T_dab0c6f8_2977_11e9_bb69_44032cd22778level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row2_col0" class="data row2 col0" >3</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row2_col1" class="data row2 col1" >VP -> V NP •</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row2_col2" class="data row2 col2" >1</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row2_col3" class="data row2 col3" >complete from (2) and S(2)(3)</td>
#     </tr>    <tr>
#         <th id="T_dab0c6f8_2977_11e9_bb69_44032cd22778level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row3_col0" class="data row3 col0" >4</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row3_col1" class="data row3 col1" >S -> NP VP •</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row3_col2" class="data row3 col2" >0</td>
#         <td id="T_dab0c6f8_2977_11e9_bb69_44032cd22778row3_col3" class="data row3 col3" >complete from (3) and S(1)(2)</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# #### Поскольку мы получили одно из самых верхних правил (S -> NP VP), это предложение порождается нашей грамматикой
# #### Можно также построить схему Earley parser с помощью стандартных средств, но она будет укороченной:

# %%
cp_verbose = nltk.EarleyChartParser(grammar, trace=21, trace_chart_width=100)
print_parses(cp_verbose, "Вася читает мою книгу")
# Out:
# |.        Вася       .       читает      .        мою        .       книгу       .|
# Leaf Init Rule:
# |[-------------------]                   .                   .                   .| [0:1] 'Вася'
# |.                   [-------------------]                   .                   .| [1:2] 'читает'
# |.                   .                   [-------------------]                   .| [2:3] 'мою'
# |.                   .                   .                   [-------------------]| [3:4] 'книгу'
# Top Down Init Rule:
# |>                   .                   .                   .                   .| [0:0] S  -> * NP VP
# |>                   .                   .                   .                   .| [0:0] S  -> * NP V
# |>                   .                   .                   .                   .| [0:0] S  -> * VP
#
# * Processing queue: 0
#
# Predictor Rule:
# |>                   .                   .                   .                   .| [0:0] VP -> * V NP
# |>                   .                   .                   .                   .| [0:0] VP -> * V VP
# |>                   .                   .                   .                   .| [0:0] VP -> * V N
# Predictor Rule:
# |>                   .                   .                   .                   .| [0:0] NP -> * ADJ N
# |>                   .                   .                   .                   .| [0:0] NP -> * ADJ NP
# |>                   .                   .                   .                   .| [0:0] NP -> * 'Вася'
#
# * Processing queue: 1
#
# Scanner Rule:
# |[-------------------]                   .                   .                   .| [0:1] NP -> 'Вася' *
# Completer Rule:
# |[------------------->                   .                   .                   .| [0:1] S  -> NP * VP
# |[------------------->                   .                   .                   .| [0:1] S  -> NP * V
# Predictor Rule:
# |.                   >                   .                   .                   .| [1:1] V  -> * 'читает'
# Predictor Rule:
# |.                   >                   .                   .                   .| [1:1] VP -> * V NP
# |.                   >                   .                   .                   .| [1:1] VP -> * V VP
# |.                   >                   .                   .                   .| [1:1] VP -> * V N
#
# * Processing queue: 2
#
# Scanner Rule:
# |.                   [-------------------]                   .                   .| [1:2] V  -> 'читает' *
# Completer Rule:
# |[---------------------------------------]                   .                   .| [0:2] S  -> NP V *
# |.                   [------------------->                   .                   .| [1:2] VP -> V * NP
# |.                   [------------------->                   .                   .| [1:2] VP -> V * VP
# |.                   [------------------->                   .                   .| [1:2] VP -> V * N
# Predictor Rule:
# |.                   .                   >                   .                   .| [2:2] VP -> * V NP
# |.                   .                   >                   .                   .| [2:2] VP -> * V VP
# |.                   .                   >                   .                   .| [2:2] VP -> * V N
# Predictor Rule:
# |.                   .                   >                   .                   .| [2:2] NP -> * ADJ N
# |.                   .                   >                   .                   .| [2:2] NP -> * ADJ NP
# Predictor Rule:
# |.                   .                   >                   .                   .| [2:2] ADJ -> * 'мою'
#
# * Processing queue: 3
#
# Scanner Rule:
# |.                   .                   [-------------------]                   .| [2:3] ADJ -> 'мою' *
# Completer Rule:
# |.                   .                   [------------------->                   .| [2:3] NP -> ADJ * N
# |.                   .                   [------------------->                   .| [2:3] NP -> ADJ * NP
# Predictor Rule:
# |.                   .                   .                   >                   .| [3:3] NP -> * ADJ N
# |.                   .                   .                   >                   .| [3:3] NP -> * ADJ NP
# Predictor Rule:
# |.                   .                   .                   >                   .| [3:3] N  -> * 'книгу'
#
# * Processing queue: 4
#
# Scanner Rule:
# |.                   .                   .                   [-------------------]| [3:4] N  -> 'книгу' *
# Completer Rule:
# |.                   .                   [---------------------------------------]| [2:4] NP -> ADJ N *
# Completer Rule:
# |.                   [-----------------------------------------------------------]| [1:4] VP -> V NP *
# Completer Rule:
# |[===============================================================================]| [0:4] S  -> NP VP *
# (S (NP Вася) (VP (V читает) (NP (ADJ мою) (N книгу))))

# %% [markdown]
# ### Убедимся в том, что наша грамматика работает. Воспользуемся EarleyChartParser-ом

# %%
cp = nltk.EarleyChartParser(grammar)
for sent in sents:
    print(sent + ':')
    print_parses(cp, sent)
    print()
# Out:
# Вася читает мою книгу:
# (S (NP Вася) (VP (V читает) (NP (ADJ мою) (N книгу))))
#
# Напиши какое-нибудь письмо:
# (S (VP (V Напиши) (NP (ADJ какое-нибудь) (N письмо))))
#
# Этот веселый мальчик идет:
# (S (NP (ADJ Этот) (NP (ADJ веселый) (N мальчик))) (V идет))
#
# Он любит читать всякие книги:
# (S
#   (NP Он)
#   (VP (V любит) (VP (V читать) (NP (ADJ всякие) (N книги)))))

# %% [markdown]
# #### Результаты работы парсера совпадают с приведённым выше пошаговым разбором алгоритма

# %% [markdown]
# #### 3. Можно улучшить работу парсера с новыми словами, если использовать морфологический анализатор, который поможет определить часть речи слова и, тем самым, позволит добавлять правила перевода нетерминалов в терминальные новые слова, при это ключевые правила останутся неизменными, т.к. они не затрагивают терминальные веришны. К примеру, при нахождении нового прилагательного X можно будет просто добавить новое правило ADJ -> X. В результате предложение можно будет разобрать.

# %% [markdown]
# #### Также вместо того, чтобы для каждой формы слова (а уж тем более для слов с заглавной и со строчной буквы) добавлять в грамматику своё правило перехода нетерминальной вершины в терминальную форму слова, достаточно завести только одно правило перевода нетерминальной вершины в стандартную форму слова (для глаголов -- в инфинитив, для существительных -- в им. падеж ед. числа и т.д.)

# %% [markdown]
# #### Хотя на самом деле в правилах без исключений можно завести id частей речи, чтобы во время распар(с/ш)ивания предложения просто обращаться к морфологической информации (части речи) и в зависимости от этого разбирать предложение. К примеру, последние 4 правила в rules можно было бы переформулировать следующим образом:
# ##### ADJ -> id_adjective OR id_possessive_pronoun
# ##### N -> id_noun
# ##### NP -> id_noun_собственное OR id_pronoun
# ##### V -> id_verb
# ##### Тогда, получив предложение с глаголом 'читает' и видя правило V -> id_verb, мы сразу можем вывести правило V -> 'читает'

# %% [markdown]
# #### 4. Неоднозначный выбор есть там, где есть омонимия. К примеру, если мы возьмём форму "мой", то она может быть формой глагола или формой прилагательного (притяжательного местоимения). И тогда предложение "Я вижу мой красивый дом" будет разбираться двояко. Убедимся в этом, расширив грамматику и подав это предложение на вход EarleyChartParser-у.

# %%
# первое правило в своей грамматике я не использовал, однако для демонстрации омонимии оно хорошо подходит
add_rules = """
    S -> N V
    ADJ -> 'мой' | 'красивый'
    N -> 'дом' | 'блины' | 'пила'
    V -> 'вижу' | 'мой' | 'мою' | 'пила'
    NP -> 'Я'
""".split('\n')

# %%
new_grammar = nltk.CFG.fromstring('\n'.join(rules + add_rules))

# %%
new_cp = nltk.EarleyChartParser(new_grammar)
sent = 'Я вижу мой красивый дом'
print_parses(new_cp, sent)
# Out:
# (S (NP Я) (VP (V вижу) (VP (V мой) (NP (ADJ красивый) (N дом)))))
# (S (NP Я) (VP (V вижу) (NP (ADJ мой) (NP (ADJ красивый) (N дом)))))

# %%
# Наша грамматика не порождает неконфигурациональные ИГ, однако порождает два глагола подряд (случай типа "люблю делать")
sent = "мою мою книгу"
print_parses(new_cp, sent)
# Out:
# (S (VP (V мою) (NP (ADJ мою) (N книгу))))
# (S (VP (V мою) (VP (V мою) (N книгу))))

# %% [markdown]
# #### Омонимия глагола с существительным наблюдается в форме "печь". У предложения "Он любит печь (,) блины" будет 2 разбора

# %%
sent = "пила пила"
print_parses(new_cp, sent)
# Out:
# (S (N пила) (V пила))
# (S (VP (V пила) (N пила)))
