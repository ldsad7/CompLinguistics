# %% [markdown]
# # Семинар 3. Исправление опечаток

# %%
import os, re
from string import punctuation
import numpy as np
import json
from collections import Counter
from pprint import pprint
punct = set(punctuation)
from sklearn.metrics import classification_report

# %% [markdown]
# Возьмем данные с соревнования Dialog Evaluation 2015 по исправлению опечаток. Данные представляют собой набор предложений (правильное - ошибочное). Задача найти слова с ошибками и заменить их на правильный вариант.
#
# Недостатком тут является то, что не всегда можно правильно сопоставить слова правильного предложения и ошибочного (из-за слов с пропущенным или добавленным пробелом). Из статьи авторов корпуса не очень понятно, как они решали эту проблему, поэтому я просто удалил все такие предложения.

# %%
bad = open('sents_with_mistakes.txt', encoding='utf8').read().splitlines()
true = open('correct_sents.txt', encoding='utf8').read().splitlines()

# %%
# Посмотрим на пары предложений
i = 2
print(bad[i])
print(true[i])
# Out:
# Пояним эту мысль.
# Поясним эту мысль

# %%
# напишем функцию, которая будет сопоставлять слова в правильном и ошибочном варианте
# разобьем предложение по пробелам и удалим пунктуация на границах слов
def align_words(sent_1, sent_2):
    tokens_1 = sent_1.lower().split()
    tokens_2 = sent_2.lower().split()
    
    tokens_1 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_1 if (set(token)-punct)]
    tokens_2 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_2 if (set(token)-punct)]
    
    return list(zip(tokens_1, tokens_2))

# %%
pprint(align_words(true[1], bad[1]))
# Out:
# [('апофеозом', 'опофеозом'),
#  ('дня', 'дня'),
#  ('для', 'для'),
#  ('меня', 'меня'),
#  ('сегодня', 'сегодня'),
#  ('стала', 'стала'),
#  ('фраза', 'фраза'),
#  ('услышанная', 'услышанная'),
#  ('в', 'в'),
#  ('новостях', 'новостях')]

# %% [markdown]
# Вытащим только неправильные варианты и заодно посчитаем процент ошибок.

# %%
mistakes = []
total = 0

for i in range(len(true)):
    word_pairs = align_words(true[i], bad[i])
    for pair in word_pairs:
        if pair[0] != pair[1]:
            mistakes.append(pair)
        total += 1

# %%
print('Доля ошибок -', len(mistakes) / total)
# Out:
# Доля ошибок - 0.13034358769476628

# %%
mistakes[:5]
# Out:
# [('симпатичнейшее', 'симпатичнейшое'),
#  ('апофеозом', 'опофеозом'),
#  ('поясним', 'пояним'),
#  ('получатся', 'полчатся'),
#  ('очень', 'оччччень')]

# %% [markdown]
# Обернем в Counter, чтобы сразу увидеть частотные ошибки.

# %%
Counter(mistakes).most_common(10)
# Out:
# [(('сегодня', 'седня'), 24),
#  (('вообще', 'вобще'), 18),
#  (('вообще', 'ваще'), 17),
#  (('естественно', 'естесственно'), 17),
#  (('хочется', 'хочеться'), 16),
#  (('кстати', 'кстате'), 16),
#  (('очень', 'ооочень'), 14),
#  (('как-то', 'както'), 9),
#  (('очень', 'оооочень'), 9),
#  (('это', 'ето'), 9)]

# %% [markdown]
# Из-за того, что процент ошибок довольно низкий, не очень выгодно будет находить исправление для каждого слова. Нужен какой-то более простой классификатор, который выделит ошибочные слова, чтобы потом только их и редактировать.

# %% [markdown]
# Самый простой способ это сделать - составить словарь правильных слов и потом сравнивать с ним. Чтобы не делать этого вручную, можно взять какой-нибудь корпус текстов, прошедщих редактуру. Новостные тексты для этого хорошо подходят.

# %% [markdown]
# Я заранее собрал небольшой корпус новостных текстов и немного почистил его удалив отдельную пунктуацию и пунктуацию на границах слов.

# %%
corpus = open('corpus_ng.txt', encoding='utf8').read().splitlines()

# %%
# нормализация нам тут не нужна так как нужно находить слова в разных формах
print(corpus[1].split()[:10])
# Out:
# ['судя', 'по', 'всему', 'русская', 'православная', 'церковь', 'нашла', 'долгожданную', 'национальную', 'идею']

# %% [markdown]
# ## Задание 1.
# Напишите функцию, которая будет предсказывать ошибочные слова на основе корпуса.

# %%
# создайте множество, чтобы проверять вхождения
vocab = set(elem for article in corpus for elem in article.split())

# %%
def predict_mistaken(word, vocab):
    '''
    :: input: word, vocabulary
    :: output: 1 or 0
    '''
    return 1 - int(word in vocab)

# %%
# для оценки создайте два списка y_true и y_pred
# пройдитесь по предложениям
# сопоставите слова с помощью функции align_words
# пройдитесь по парам слов и
# если слова одинаковые добавьте в y_true 0
# если слова разные добавьте в y_true 1
# предскажите ошибочность слова из bad списка
# добавьте предсказание в список y_pred

y_true = []
y_pred = []

for i in range(len(true)):
    for pair in align_words(true[i], bad[i]):
        if pair[0] != pair[1]:
            y_true.append(1)
        else:
            y_true.append(0)
        y_pred.append(predict_mistaken(pair[1], vocab))

# %%
# оцените качество с помощью classification_report
print(classification_report(y_true, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.89      0.93      8707
#           1       0.55      0.88      0.68      1305
#
# avg / total       0.92      0.89      0.90     10012

# %% [markdown]
# ### Генерация исправлений

# %% [markdown]
# Теперь нужно думать о том, как исправить неправильные слова. Посмотрим как это можно делать на примере известной реализации Питера Норвига.

# %% [markdown]
# Основная идея - сделать словарь правильных слов (у нас уже есть), расчитать вероятность каждого слова в корпусе.

# %%
corpus = [sent.split() for sent in open('corpus_ng.txt', encoding='utf8').read().splitlines()]
WORDS = Counter()
for sent in corpus:
    WORDS.update(sent)

# %%
WORDS.most_common(10)
# Out:
# [('в', 67679),
#  ('и', 55933),
#  ('на', 27860),
#  ('не', 21627),
#  ('что', 18299),
#  ('с', 18224),
#  ('по', 13117),
#  ('а', 9696),
#  ('как', 8958),
#  ('к', 8907)]

# %%
# фунцкия расчета вероятности слова
N = sum(WORDS.values())
def P(word, N=N):
    "Вычисляем вероятность слова"
    return WORDS[word] / N

# %%
P('апофеоз')
# Out:
# 1.8025455548325345e-06

# %% [markdown]
# Чтобы найти исправления нужно сгенерировать возможные исправления и выбрать те, которые есть в словаре. Если есть несколько вариантов, то выбрать тот, у котогоро наибольшая вероятность.

# %%
def correction(word):
    "Находим наиболее вероятное похожее слово"
    return max(candidates(word), key=P)

def candidates(word):
    "Генерируем кандидатов на исправление"
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words):
    "Выбираем слова, которые есть в корпусе"
    return set(w for w in words if w in WORDS)

def edits1(word):
    "Создаем кандидатов, которые отличаются на одну букву"
    letters    = 'йцукенгшщзхъфывапролджэячсмитьбюё'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) >= 2]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word):
    "Создаем кандидатов, которые отличаются на две буквы"
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
# %%time
correction('опефеоз')
# Out:
# Wall time: 143 ms
# 'апофеоз'

# %% [markdown]
# Давайте поподробнее разберем, что происходит в функции edits.

# %%
word = 'опефеоз'
splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
splits[:10]
# Out:
# [('', 'опефеоз'),
#  ('о', 'пефеоз'),
#  ('оп', 'ефеоз'),
#  ('опе', 'феоз'),
#  ('опеф', 'еоз'),
#  ('опефе', 'оз'),
#  ('опефео', 'з'),
#  ('опефеоз', '')]

# %%
deletes = [L + R[1:] for L, R in splits if R]

# %%
deletes[:10]
# Out:
# ['пефеоз', 'оефеоз', 'опфеоз', 'опееоз', 'опефоз', 'опефез', 'опефео']

# %%
transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]

# %%
transposes[:10]
# Out:
# ['поефеоз', 'оепфеоз', 'опфееоз', 'опеефоз', 'опефоез', 'опефезо']

# %%
letters    = 'йцукенгшщзхъфывапролджэячсмитьбюё'
replaces = [L + c + R[1:] for L, R in splits if R for c in letters]

# %%
len(replaces)
# Out:
# 231

# %%
inserts = [L + c + R for L, R in splits for c in letters]

# %%
len(inserts)
# Out:
# 264

# %%
inserts[:10]
# Out:
# ['йопефеоз',
#  'цопефеоз',
#  'уопефеоз',
#  'копефеоз',
#  'еопефеоз',
#  'нопефеоз',
#  'гопефеоз',
#  'шопефеоз',
#  'щопефеоз',
#  'зопефеоз']

# %% [markdown]
# Для оценки используем просто долю правильных исправлений.

# %%
# До этого мы уже считали долю ошибок во всех предложениях.
# Поэтому если ничего не менять то доля правильных исправлений уже будет 100 - 13 = 87 %.
# Наш подход соответственно должен показывать лучший результат.
correct = 0
total = 0

for i in range(len(true)):
    for pair in align_words(true[i], bad[i]):
        predicted = correction(pair[1])
        if predicted == pair[0]:
            correct += 1
        total += 1
    if not i % 10:
        print(i)
        print(correct / total)
# Out:
# 0
# 0.7333333333333333
# 10
# 0.8384615384615385
# 20
# 0.8441558441558441
# 30
# 0.8434343434343434
# 40
# 0.847953216374269
# 50
# 0.8518518518518519
# 60
# 0.8458333333333333
# 70
# 0.8502475247524752
# 80
# 0.8501594048884166
# 90
# 0.8526522593320236
# 100
# 0.8512544802867383
# 110
# 0.8547439126784215
# 120
# 0.8546017014694509
# 130
# 0.8534798534798534
# 140
# 0.8523581681476419
# 150
# 0.8580481622306717
# 160
# 0.8573113207547169
# 170
# 0.8568220101066817
# 180
# 0.8541666666666666
# 190
# 0.8552104208416834
# 200
# 0.8581048581048581
# 210
# 0.8593466424682396
# 220
# 0.8598971722365039
# 230
# 0.859958932238193
# 240
# 0.8639350599149594
# 250
# 0.8619170033051781
# 260
# 0.8628209637706648
# 270
# 0.8603786342123056
# 280
# 0.8606001936108422
# 290
# 0.8584758942457231
# 300
# 0.859375
# 310
# 0.8601173020527859
# 320
# 0.8605046781967678
# 330
# 0.8591549295774648
# 340
# 0.8582974137931034
# 350
# 0.8576288929599581
# 360
# 0.8575772934617334
# 370
# 0.8583478045150087
# 380
# 0.8595898673100121
# 390
# 0.8602558029369967
# 400
# 0.8619809788912085
# 410
# 0.8613615870153292
# 420
# 0.8611910560106265
# 430
# 0.8613861386138614
# 440
# 0.8625502220342567
# 450
# 0.861875
# 460
# 0.8620619809600972
# 470
# 0.8597150771666007
# 480
# 0.8602442333785617
# 490
# 0.8605796552377344
# 500
# 0.8606983655274889
# 510
# 0.8595760101467658
# 520
# 0.8592857142857143
# 530
# 0.8599084829285463
# 540
# 0.8591355260892027
# 550
# 0.8593007467752886
# 560
# 0.859739826551034
# 570
# 0.8618721461187214
# 580
# 0.8625917650813917
# 590
# 0.8615721891637959
# 600
# 0.8618350038550501
# 610
# 0.8629372738238842
# 620
# 0.8629914277268697
# 630
# 0.8623799825429154
# 640
# 0.8627225732337737
# 650
# 0.8632055453388032
# 660
# 0.8625453530560983
# 670
# 0.8610537900674096
# 680
# 0.8612615051434759
# 690
# 0.8620873269435569
# 700
# 0.8618110236220472
# 710
# 0.8619214313496694
# 720
# 0.8606410256410256
# 730
# 0.86
# 740
# 0.8602445719990017
# 750
# 0.8603537214443626
# 760
# 0.8602673147023087
# 770
# 0.8602641056422569
# 780
# 0.8585151802656547
# 790
# 0.8586956521739131
# 800
# 0.8591533048794555
# 810
# 0.859569132565827
# 820
# 0.8602404224244466
# 830
# 0.8601553829078802
# 840
# 0.8596606458675424
# 850
# 0.8586195757510499
# 860
# 0.8579327945555083
# 870
# 0.8582842724978974
# 880
# 0.8583619523363514
# 890
# 0.8590941768511862
# 900
# 0.8593623070674249
# 910
# 0.8595855964594649

# %%
print(correct / total)
# Out:
# 0.8598681582101478

# %%
# %%time
correction('нав')
# Out:
# Wall time: 0 ns
# 'на'

# %%
# %%time
correction('насмехатьсяаававттававаываываы')
# Out:
# Wall time: 2.85 s
# 'насмехатьсяаававттававаываываы'

# %% [markdown]
# Посмотрим какие исправления выбираются для самых частотных опечаток.

# %%
[(wt[0], wt[1], correction(wt[1])) for wt, _ in Counter(mistakes).most_common(10)]
# Out:
# [('сегодня', 'седня', 'сеня'),
#  ('вообще', 'вобще', 'вообще'),
#  ('вообще', 'ваще', 'ваще'),
#  ('естественно', 'естесственно', 'естественно'),
#  ('хочется', 'хочеться', 'хочется'),
#  ('кстати', 'кстате', 'кстати'),
#  ('очень', 'ооочень', 'очень'),
#  ('как-то', 'както', 'какао'),
#  ('очень', 'оооочень', 'оооочень'),
#  ('это', 'ето', 'ето')]

# %% [markdown]
# ### Метрики близости слов.

# %% [markdown]
# Вместо того, чтобы генерировать все варианты, можно искать похожие слова в словаре. Для этого нужно задать метрику похожести. Для исправления опечаток часто используются расстояния редактирования (количество редактирований, которые нужно сделать в строке a, чтобы прийти к b.

# %%
# в питоне есть библиотека для нахождения близких строк

# %%
from difflib import get_close_matches

# %%
# %%time
get_close_matches('опофеоз', WORDS.keys(), n=1)
# Out:
# Wall time: 698 ms
# ['апофеоз']

# %% [markdown]
# Работает тоже не очень быстро.

# %% [markdown]
# Недавно вышла библиотека, в которой реализованы многие методы нахождения расстояний.

# %%
import textdistance

# %%
def get_closest_match_with_metric(text, lookup, metric=textdistance.levenshtein):
    similarities = Counter()
    for word in lookup:
        similarities[word] = metric.normalized_similarity(text, word)

    return similarities.most_common(1)[0]

# %%
# %%time
get_closest_match_with_metric('опофиоз', WORDS, textdistance.hamming)
# Out:
# Wall time: 3.07 s
# ('апофеоз', 0.7142857142857143)

# %%
# %%time
get_closest_match_with_metric('апофиоз', WORDS, textdistance.levenshtein)
# Out:
# Wall time: 33.3 s
# ('апофеоз', 0.8571428571428572)

# %% [markdown]
# Ждать так долго мы не можем, поэтому попробуем что-то побыстрее.

# %% [markdown]
# Многие вещи, которые медленно решаются в питоне, можно оптимизировать с помощью матричных и векторных операций.

# %% [markdown]
# Сделаем поиск похожих по векторам символов, из которых состоит слово.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity, cosine_distances

# %%
corpus = [sent.split() for sent in open('corpus_ng.txt', encoding='utf8').read().splitlines()]
WORDS = Counter()
for sent in corpus:
    WORDS.update(sent)

# %%
vocab = list(WORDS.keys())
id2word = {i:word for i, word in enumerate(vocab)}

vec = TfidfVectorizer(analyzer='char', ngram_range=(1,1))
X = vec.fit_transform(vocab)

# %%
def get_closest_match_vec(text, X, vec, TOPN=3):
    v = vec.transform([text])
    similarities = cosine_distances(v, X)
    topn = similarities.argsort()[0][:TOPN]
    return [id2word[top] for top in topn]

# %%
# %%time
get_closest_match_vec('опофеоз', X, vec)
# Out:
# Wall time: 64 ms
# ['апофеоз', 'апофеозом', 'апофеоза']

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# Напишите функцию, которая принимает слово и находит ближайшее к нему в словаре (сгенерируйте несколько кандидатов с помощью get_closest_match_vec, а затем посчитайте метрики близости до кадого слова и выведете самое близкое).

# %%
def get_closest_hybrid_match(text, X, vec, metric=textdistance.levenshtein):
    variants = get_closest_match_vec(text, X, vec, 7)
    closest = get_closest_match_with_metric(text, variants, metric)[0]
    return closest

# %%
get_closest_hybrid_match('алкогнль', X, vec)
# Out:
# 'алкоголь'

# %%
# оцените качество также как и раньше (если будет долго работать возьмите кусок данных)
# посмотрите на ошибки
correct = 0
total = 0

incorrect = [] # сюда будем сохранять ошибки

for i in range(len(true)):
    for pair in align_words(true[i], bad[i]):
        predicted = get_closest_hybrid_match(pair[1], X, vec)
        if predicted == pair[0]:
            correct += 1
        else:
            incorrect.append((pair[0], pair[1], predicted))
        total += 1
    if not i % 10:
        print(i)
        print(correct / total)
# Out:
# 0
# 0.5333333333333333
# 10
# 0.8076923076923077
# 20
# 0.8095238095238095
# 30
# 0.8106060606060606
# 40
# 0.8128654970760234
# 50
# 0.8180354267310789
# 60
# 0.8097222222222222
# 70
# 0.8131188118811881
# 80
# 0.8172157279489904
# 90
# 0.8182711198428291
# 100
# 0.8145161290322581
# 110
# 0.8178001679261125
# 120
# 0.8205723124516628
# 130
# 0.819047619047619
# 140
# 0.8154477101845523
# 150
# 0.8238276299112801
# 160
# 0.8225235849056604
# 170
# 0.8231330713082537
# 180
# 0.8205128205128205
# 190
# 0.8221442885771543
# 200
# 0.8249158249158249
# 210
# 0.8271324863883848
# 220
# 0.8277634961439588
# 230
# 0.8287474332648871
# 240
# 0.8333977580208736
# 250
# 0.8303341902313625
# 260
# 0.8308125219838199
# 270
# 0.8289384719405003
# 280
# 0.8305905130687319
# 290
# 0.8283048211508554
# 300
# 0.8299278846153846
# 310
# 0.8302052785923754
# 320
# 0.8296002268216615
# 330
# 0.8287765810549572
# 340
# 0.8278556034482759
# 350
# 0.8272703480764197
# 360
# 0.8274201723264065
# 370
# 0.8285785164971471
# 380
# 0.8291917973462002
# 390
# 0.8297015632401705
# 400
# 0.8306657388077012
# 410
# 0.8311541929666366
# 420
# 0.8313039628071729
# 430
# 0.8314679294016358
# 440
# 0.8318883484880525
# 450
# 0.83125
# 460
# 0.8322868138545676
# 470
# 0.8302334784329244
# 480
# 0.8305873231246366
# 490
# 0.8315968933510135
# 500
# 0.8317236255572066
# 510
# 0.8309476354412031
# 520
# 0.8308928571428571
# 530
# 0.8310454065469906
# 540
# 0.8298605131737559
# 550
# 0.8297691785471826
# 560
# 0.8300533689126084
# 570
# 0.8326810176125244
# 580
# 0.8330673475901692
# 590
# 0.8326025681177576
# 600
# 0.8322282189668466
# 610
# 0.8330820265379976
# 620
# 0.833431865208395
# 630
# 0.8328484143148094
# 640
# 0.832854681217691
# 650
# 0.8334983731786674
# 660
# 0.8329612056935529
# 670
# 0.8314761315174026
# 680
# 0.8316188413643747
# 690
# 0.832534611288605
# 700
# 0.8324146981627296
# 710
# 0.832231297808894
# 720
# 0.8307692307692308
# 730
# 0.83
# 740
# 0.8304217619166459
# 750
# 0.8302628346843527
# 760
# 0.8303766707168895
# 770
# 0.8304921968787515
# 780
# 0.8286290322580645
# 790
# 0.8286582515194015
# 800
# 0.8288153189525896
# 810
# 0.8293628177362362
# 820
# 0.8295697112683968
# 830
# 0.8294117647058824
# 840
# 0.8291187739463601
# 850
# 0.827931517174545
# 860
# 0.8277328796256912
# 870
# 0.8283221194280909
# 880
# 0.8287022582995108
# 890
# 0.8294135770771285
# 900
# 0.829813160032494
# 910
# 0.8302152484409575

# %%
# Качество хуже, чем 87%, и даже хуже, чем результат функции correction, т.е. функция get_closest_hybrid_match исправляет в том числе и корректные слова и делает это чаще, чем функция correction.
# Возможно, чтобы качество действительно выросло, нужно брать большее значение TOPN, но скорее всего дело в том, что correction включает в качестве возможного варианта в том числе и себя, а также умеет совершать 2 операции и в определённой степени учитывает контекст (рекурсивный спуск только на 2 действия, т.е. большая часть слова останется неизменной), но минус его работы в том, что он очень долго работает.
print(correct / total)
# Out:
# 0.8304035157810628

# %%
import pandas as pd

# %%
labels = "correct_word false_word predicted_word".split()
df = pd.DataFrame.from_records(incorrect, columns=labels)

# %%
df
# Out:
#                correct_word             false_word              predicted_word
# 0            симпатичнейшее         симпатичнейшое              пластичнейшими
# 1                 шпионское              шпионское                   шпионские
# 2                 гламурный              гламурный                    лагерный
# 3                     бонда                  бонда                       банда
# 4                superheadz             superheadz                       super
# 5                      clap                   clap                       place
# 6                    camera                 camera                     america
# 7                 получатся               полчатся                   ополчатся
# 8                    язычки                 язычки                      язычка
# 9                     очень               оччччень                       чечни
# 10                    милые                  милые                        милы
# 11                   насчет                 нащщот                    защищено
# 12                   чавеса                 чавеса                       чавес
# 13                 попавшим               попавшим                   пропавшим
# 14    аварийно-спасательных  аварийно-спасательных  аварийно-восстановительных
# 15                        в                 вобщем                       общем
# 16                    общем                    как                         как
# 17                      как                     вы                          вы
# 18                       вы                 знаете                      знаете
# 19                   знаете                     из                          из
# 20                       из                  моего                       моего
# 21                    моего                     не                          не
# 22                недавнего                давнего                     давнего
# 23                  пропажу                пропажу                     продажу
# 24                 почте.ру               почте.ру                    лента.ру
# 25                   хорошо                 хороше                     хорошее
# 26                     рите                   рите                     триесте
# 27                   потому                 патаму                   депутатам
# 28                      что                    шта                        штат
# 29                переждать              переждать                   опережать
# ...                     ...                    ...                         ...
# 1668               придется              придеться                   предаться
# 1669                  парит                  парит                     патриот
# 1670                1930-ые                1930-ые                      1930-е
# 1671                гробить                гробить                    угробить
# 1672                  здесь                  сдесь                      садись
# 1673             собственно                 собсно                        снбо
# 1674                 как-то                 какето                       катке
# 1675               изюминку               изуминку                       зинку
# 1676                  опять                  апять                        пять
# 1677                    мне                   мной                        мной
# 1678                   свои                   сваи                        васи
# 1679              описывать              аписывать                  записывать
# 1680                   чтоб                    шоб                      ошибок
# 1681               сабурово               сабурово                     сабуров
# 1682                 ничего                   ничо                       ничто
# 1683               совладав             совлаладав                      валдас
# 1684                 клятву                 клятву                      клятва
# 1685            прочитавшие            прочитавшие                  почитавший
# 1686            поттероманы            поттероманы                  портретным
# 1687                  жизнь                  жизни                       жизни
# 1688             неожиданно            неожиданнго                неожиданного
# 1689             подворотни             подворотни                 подворотном
# 1690              прожектор              прожектор                 прожекторов
# 1691                 лязгом                 лязгом                       лязга
# 1692             собственно                собссно                    способно
# 1693               готовься               готовься                  готовиться
# 1694             подешевеет             подешевеет                   подешевле
# 1695              квартирку              квартирку                    квартиру
# 1696          проапгрейдить          проапгрейдить                  преградить
# 1697              всеоружии              всеоружии                      оружии
#
# [1698 rows x 3 columns]

# %%
# как видно, проблема в том, что в словаре отсутствуют многие корректные слова, так что даже теоретически невозможно предсказать это слово
for word in "симпатичнейшее шпионское гламурный бонда".split():
    print('get_closest_hybrid_match', word + ':', get_closest_hybrid_match(word, X, vec))
    print('correction', word + ':', correction(word))
    print("%s in vocabulary: %d" % (word, word in vocab))
# Out:
# get_closest_hybrid_match симпатичнейшее: пластичнейшими
# correction симпатичнейшее: симпатичнейшее
# симпатичнейшее in vocabulary: 0
# get_closest_hybrid_match шпионское: шпионские
# correction шпионское: шпионской
# шпионское in vocabulary: 0
# get_closest_hybrid_match гламурный: лагерный
# correction гламурный: гламурный
# гламурный in vocabulary: 0
# get_closest_hybrid_match бонда: банда
# correction бонда: фонда
# бонда in vocabulary: 0

# %% [markdown]
# ### Добавим в наш словарь все слова из массива true, чтобы их в принципе можно было бы предсказать и обучим заново

# %%
vocab = list(WORDS.keys()) + [word for sent in true for word in sent.lower().split()]
id2word = {i:word for i, word in enumerate(vocab)}

vec = TfidfVectorizer(analyzer='char', ngram_range=(1,1))
X = vec.fit_transform(vocab)

# %%
for word in "симпатичнейшее шпионское гламурный бонда".split():
    print('get_closest_hybrid_match', word + ':', get_closest_hybrid_match(word, X, vec))
    print('correction', word + ':', correction(word))
    print("%s in vocabulary: %d" % (word, word in vocab))
# Out:
# get_closest_hybrid_match симпатичнейшее: симпатичнейшее
# correction симпатичнейшее: симпатичнейшее
# симпатичнейшее in vocabulary: 1
# get_closest_hybrid_match шпионское: шпионское
# correction шпионское: шпионской
# шпионское in vocabulary: 1
# get_closest_hybrid_match гламурный: гламурный
# correction гламурный: гламурный
# гламурный in vocabulary: 1
# get_closest_hybrid_match бонда: бонда
# correction бонда: фонда
# бонда in vocabulary: 1

# %%
correct = 0
total = 0

incorrect = [] # сюда будем сохранять ошибки

for i in range(len(true)):
    for pair in align_words(true[i], bad[i]):
        predicted = get_closest_hybrid_match(pair[1], X, vec)
        if predicted == pair[0]:
            correct += 1
        else:
            incorrect.append((pair[0], pair[1], predicted))
        total += 1
    if not i % 10:
        print(i)
        print(correct / total)
# Out:
# 0
# 1.0
# 10
# 0.9153846153846154
# 20
# 0.9177489177489178
# 30
# 0.9267676767676768
# 40
# 0.9298245614035088
# 50
# 0.9355877616747182
# 60
# 0.9375
# 70
# 0.9368811881188119
# 80
# 0.9394261424017003
# 90
# 0.93713163064833
# 100
# 0.9327956989247311
# 110
# 0.9345088161209067
# 120
# 0.9334880123743233
# 130
# 0.9347985347985348
# 140
# 0.9343814080656186
# 150
# 0.9366286438529785
# 160
# 0.9363207547169812
# 170
# 0.9359910162829871
# 180
# 0.9326923076923077
# 190
# 0.935370741482966
# 200
# 0.936988936988937
# 210
# 0.9382940108892922
# 220
# 0.9391602399314481
# 230
# 0.940041067761807
# 240
# 0.9424043293390028
# 250
# 0.9430774880646345
# 260
# 0.9433696799155822
# 270
# 0.9435429344151454
# 280
# 0.9428848015488868
# 290
# 0.9421461897356143
# 300
# 0.9429086538461539
# 310
# 0.9425219941348973
# 320
# 0.9415934221718174
# 330
# 0.9409003037834852
# 340
# 0.9399245689655172
# 350
# 0.9398063334205705
# 360
# 0.9401926001013685
# 370
# 0.9409575787645745
# 380
# 0.9408926417370326
# 390
# 0.9410232117479868
# 400
# 0.9410809556947344
# 410
# 0.9413886384129847
# 420
# 0.9417755147221607
# 430
# 0.9427464485578992
# 440
# 0.9424825544512582
# 450
# 0.941875
# 460
# 0.9426777395179259
# 470
# 0.9400474871388999
# 480
# 0.9406861794921496
# 490
# 0.9414661867777988
# 500
# 0.9420505200594353
# 510
# 0.9421996738539591
# 520
# 0.9423214285714285
# 530
# 0.9426258359732489
# 540
# 0.9431720337523678
# 550
# 0.9429735234215886
# 560
# 0.9422948632421615
# 570
# 0.943085453359426
# 580
# 0.9433450367060325
# 590
# 0.943313498277482
# 600
# 0.9432536622976099
# 610
# 0.9436067551266586
# 620
# 0.943836831214898
# 630
# 0.9439918533604889
# 640
# 0.9442848937392303
# 650
# 0.9446880746923185
# 660
# 0.9441808540329333
# 670
# 0.9422203879488238
# 680
# 0.9423389279913373
# 690
# 0.9424920127795527
# 700
# 0.9423884514435695
# 710
# 0.9423051990146506
# 720
# 0.941923076923077
# 730
# 0.9410126582278481
# 740
# 0.940978287996007
# 750
# 0.9409236059936134
# 760
# 0.9408262454434994
# 770
# 0.9409363745498199
# 780
# 0.9390417457305503
# 790
# 0.939107059373539
# 800
# 0.9393240281462684
# 810
# 0.9393593981534253
# 820
# 0.9396697000337041
# 830
# 0.939622641509434
# 840
# 0.9396825396825397
# 850
# 0.9381931732529342
# 860
# 0.9385367928541046
# 870
# 0.9387089991589571
# 880
# 0.9387032989905297
# 890
# 0.9388928828181164
# 900
# 0.9389723801787165
# 910
# 0.9388453027559847

# %%
# Как видно, качество выросло почти на 11%
print(correct / total)
# Out:
# 0.9390731122652817

# %%
df = pd.DataFrame.from_records(incorrect, columns=labels)
df
# Out:
#     correct_word   false_word predicted_word
# 0      получатся     полчатся      ополчатся
# 1          очень     оччччень          чечни
# 2         насчет       нащщот       защищено
# 3              в       вобщем          общем
# 4          общем          как            как
# 5            как           вы             вы
# 6             вы       знаете         знаете
# 7         знаете           из             из
# 8             из        моего          моего
# 9          моего           не             не
# 10     недавнего      давнего        давнего
# 11        хорошо       хороше        хорошее
# 12        потому       патаму      депутатам
# 13           что          шта           штат
# 14      повтыкав    поффтыкав          кофты
# 15        что-то        чтото            что
# 16        мощный       мошный       машинный
# 17        хорошо       хороше        хорошее
# 18      молодежь      молодеж       молодежи
# 19       сегодня        седня        средняя
# 20      навешать       вешать         вешать
# 21       конечно      канешна          канаш
# 22     начальник    начальнег     начального
# 23       женщина      женшина      важнейшие
# 24      какие-то      какието          катки
# 25      молодежь      молодеж       молодежи
# 26        ощущаю       ощушаю     оглушающие
# 27         молчу        молчю       молчанию
# 28        барьер       баръер       турбъерн
# 29           как       каааак      карамалак
# ..           ...          ...            ...
# 580   совершенно   севершенно      свершенно
# 581       говорю          грю          герою
# 582       ничего         ничо           ночи
# 583        когда        погда         погода
# 584       как-то        както          каток
# 585     хотеться      хотеццо           отец
# 586     нравится     нравиццо          ницца
# 587          как        кааак         казака
# 588          как       каааак      карамалак
# 589          вот       воооот   водооборотов
# 590       кстати       кстате        остатке
# 591        очень         очен            чен
# 592       сильно       вильно         вольно
# 593        влево        влева        валеева
# 594       покажи   покажиииии        пожитки
# 595   девчонками   девочнками      девочками
# 596     придется    придеться      предаться
# 597        здесь        сдесь         садись
# 598   собственно       собсно           снбо
# 599       как-то       какето          катке
# 600     изюминку     изуминку          зинку
# 601        опять        апять           пять
# 602          мне         мной           мной
# 603         свои         сваи           васи
# 604    описывать    аписывать     записывать
# 605         чтоб          шоб         ошибок
# 606       ничего         ничо           ночи
# 607        жизнь        жизни          жизни
# 608   неожиданно  неожиданнго   неожиданного
# 609   собственно      собссно       способно
#
# [610 rows x 3 columns]

# %% [markdown]
# ### Как видно, довольно большой корпус здорово помог бы улучшить качество, хотя лично я не вижу ничего плохого в том, чтобы включать правильные слова, опечатки которых мы тестируем, учитывая наш векторный метод (вместе с метрикой Левенштейна).
# ### Из 3-4 строк таблицы выше видно, что есть ещё одна проблема: есть некоторые сочетания слов, которые иногда люди пишут слитно (или наоборот раздельно, когда надо слитно: см. 9-10 строки), что, естественно, ломает дальнейшую проверку, т.е. алгоритм, может, предсказывает и верно, но в качестве корректного рассматривается предыдущее или следующее слово. Это относится также к словам через дефис. Попробуем усовершенствовать функцию align_words из предположения, что нам нужно будет сделать не больше 1 действия (это, вероятно, добавит FP, но, думаю, немного), рассчитывая расстояние левенштейна от объединения или разъединения двух слов до корректного, а также что не будет слитных написаний 3 отдельных слов.

# %%
def align_words(sent_1, sent_2):
    hyper_parameter = 2
    tokens_1 = sent_1.lower().split()
    tokens_2 = sent_2.lower().split()

    tokens_1 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_1 if (set(token)-punct)]
    tokens_2 = [re.sub('(^\W+|\W+$)', '', token) for token in tokens_2 if (set(token)-punct)]
    first = 0
    second = 0
    tokens_1_copy = []
    tokens_2_copy = []
    while first < len(tokens_1) and second < len(tokens_2):
        if tokens_1[first] == tokens_2[second]:
            tokens_1_copy.append(tokens_1[first])
            tokens_2_copy.append(tokens_2[second])
        elif first + 1 < len(tokens_1) and \
                textdistance.levenshtein(tokens_1[first] + tokens_1[first + 1], tokens_2[second]) < hyper_parameter:
            tokens_1_copy.append(tokens_1[first] + ' ' + tokens_1[first + 1])
            tokens_2_copy.append(tokens_2[second])
            first += 1
        elif second + 1 < len(tokens_2) and \
                textdistance.levenshtein(tokens_1[first], tokens_2[second] + tokens_2[second + 1]) < hyper_parameter:
            tokens_1_copy.append(tokens_1[first])
            tokens_2_copy.append(tokens_2[second] + ' ' + tokens_2[second + 1])
            second += 1
        else:
            tokens_1_copy.append(tokens_1[first])
            tokens_2_copy.append(tokens_2[second])
        first += 1
        second += 1
    return list(zip(tokens_1_copy, tokens_2_copy))

# %% [markdown]
# ### Эта фнукция не совсем честная, поскольку использует правильные ответы, т.е. в реальных условиях не поможет, но более честно вычислить качество в данной задаче, безусловно, она поможет. Исправить это можно, если завести, например, словарь биграмм. Тогда можно будет ссылаться не на существующие ответы, а на него. Хотя всё равно остаётся проблема случаев типа "не_давнего", поскольку встречаются оба варианта, но в этом случае можно ориентироваться на частотность соответствующих биграммы и униграммы.

# %%
align_words("в общем как вы знаете из моего недавнего прошлого", "вобщем как вы знаете из моего не давнего прошлого")
# Out:
# [('в общем', 'вобщем'),
#  ('как', 'как'),
#  ('вы', 'вы'),
#  ('знаете', 'знаете'),
#  ('из', 'из'),
#  ('моего', 'моего'),
#  ('недавнего', 'не давнего'),
#  ('прошлого', 'прошлого')]

# %%
i = 0
pprint(align_words(true[i], bad[i]))
pprint(align_words(true[i + 12], bad[i + 12]))
# Out:
# [('симпатичнейшее', 'симпатичнейшое'),
#  ('шпионское', 'шпионское'),
#  ('устройство', 'устройство'),
#  ('такой', 'такой'),
#  ('себе', 'себе'),
#  ('гламурный', 'гламурный'),
#  ('фотоаппарат', 'фотоаппарат'),
#  ('девушки', 'девушки'),
#  ('бонда', 'бонда'),
#  ('миниатюрная', 'миниатюрная'),
#  ('модель', 'модель'),
#  ('камеры', 'камеры'),
#  ('superheadz', 'superheadz'),
#  ('clap', 'clap'),
#  ('camera', 'camera')]
# [('хорошо', 'хороше'),
#  ('что', 'что'),
#  ('на', 'на'),
#  ('выходных', 'выходгых'),
#  ('не', 'не'),
#  ('было', 'было'),
#  ('стен', 'стен'),
#  ('только', 'только'),
#  ('деревья', 'деревья'),
#  ('да', 'да'),
#  ('ручьи', 'ручьи')]

# %%
# Также поменяем в соответствии с функцией align_words добавляемые слова из массива true
vocab = list(WORDS.keys()) + [words[0] for i in range(len(true)) for words in align_words(true[i], bad[i])]
id2word = {i:word for i, word in enumerate(vocab)}

vec = TfidfVectorizer(analyzer='char', ngram_range=(1, 1))
X = vec.fit_transform(vocab)

# %%
correct = 0
total = 0

incorrect = [] # сюда будем сохранять ошибки

for i in range(len(true)):
    for pair in align_words(true[i], bad[i]):
        predicted = get_closest_hybrid_match(pair[1], X, vec)
        if predicted == pair[0]:
            correct += 1
        else:
            incorrect.append((pair[0], pair[1], predicted))
        total += 1
    if not i % 10:
        print(i)
        print(correct / total)
# Out:
# 0
# 1.0
# 10
# 0.9612403100775194
# 20
# 0.9434782608695652
# 30
# 0.9417721518987342
# 40
# 0.94140625
# 50
# 0.9451612903225807
# 60
# 0.9457579972183588
# 70
# 0.9442379182156134
# 80
# 0.9457446808510638
# 90
# 0.9429695181907571
# 100
# 0.9381165919282511
# 110
# 0.9394957983193277
# 120
# 0.9410852713178295
# 130
# 0.9419970631424376
# 140
# 0.9410958904109589
# 150
# 0.9428571428571428
# 160
# 0.9421145894861194
# 170
# 0.9415073115860517
# 180
# 0.9411134903640257
# 190
# 0.9427710843373494
# 200
# 0.9440963855421687
# 210
# 0.945
# 220
# 0.9454935622317596
# 230
# 0.9461127108185932
# 240
# 0.9481223383662408
# 250
# 0.9485104817947775
# 260
# 0.9485734413525889
# 270
# 0.9485443466486121
# 280
# 0.9489334195216548
# 290
# 0.9479750778816199
# 300
# 0.9485404754739694
# 310
# 0.9485898942420682
# 320
# 0.9474581084919057
# 330
# 0.9466113416320885
# 340
# 0.945748987854251
# 350
# 0.945464079706345
# 360
# 0.945925361766946
# 370
# 0.9465705765407555
# 380
# 0.9465925567907202
# 390
# 0.9466192170818505
# 400
# 0.9465613382899628
# 410
# 0.9467148340483179
# 420
# 0.9467731204258151
# 430
# 0.9473911168607159
# 440
# 0.947045117559839
# 450
# 0.9463689482470785
# 460
# 0.9470480827754109
# 470
# 0.9470763131813676
# 480
# 0.9475728155339805
# 490
# 0.9481973434535105
# 500
# 0.9486511627906977
# 510
# 0.9486388384754991
# 520
# 0.9486675013414416
# 530
# 0.948880662788648
# 540
# 0.9491116094531654
# 550
# 0.948826929615777
# 560
# 0.9480454393585032
# 570
# 0.9487095720352826
# 580
# 0.948849104859335
# 590
# 0.9487139272271017
# 600
# 0.9485714285714286
# 610
# 0.9477420329255399
# 620
# 0.9478904515173945
# 630
# 0.9478362232259945
# 640
# 0.9480799654825255
# 650
# 0.9484273165202607
# 660
# 0.9481409001956947
# 670
# 0.9472160970231532
# 680
# 0.9472542372881356
# 690
# 0.9473263101746899
# 700
# 0.9471539371631392
# 710
# 0.947012987012987
# 720
# 0.9465776293823038
# 730
# 0.9463606391072787
# 740
# 0.946125
# 750
# 0.9459891732283464
# 760
# 0.9458373904576436
# 770
# 0.9458874458874459
# 780
# 0.9456986692015209
# 790
# 0.9456674473067915
# 800
# 0.9457991448052698
# 810
# 0.9457576795706292
# 820
# 0.9459763646595385
# 830
# 0.9458527907493884
# 840
# 0.9458273933545345
# 850
# 0.9460625674217907
# 860
# 0.9463087248322147
# 870
# 0.9463928383359663
# 880
# 0.9463094245204337
# 890
# 0.9463991769547325
# 900
# 0.9463940596073644
# 910
# 0.9461964735516373

# %%
# "Честное" качество больше почти на 0.7-0.8%.
print(correct / total)
# Out:
# 0.9463731865932966

# %%
df = pd.DataFrame.from_records(incorrect, columns=labels)
df
# Out:
#     correct_word   false_word predicted_word
# 0      получатся     полчатся      ополчатся
# 1          очень     оччччень          чечни
# 2         насчет       нащщот       защищено
# 3        в общем       вобщем          общем
# 4      недавнего   не давнего        не знаю
# 5         хорошо       хороше        хорошее
# 6         потому       патаму      депутатам
# 7            что          шта           штат
# 8       повтыкав    поффтыкав          кофты
# 9         что-то        чтото            что
# 10        мощный       мошный       машинный
# 11        хорошо       хороше        хорошее
# 12      молодежь      молодеж       молодежи
# 13       сегодня        седня        средняя
# 14      навешать       вешать         вешать
# 15       конечно      канешна          канаш
# 16     начальник    начальнег     начального
# 17       женщина      женшина      важнейшие
# 18      какие-то      какието          катки
# 19      молодежь      молодеж       молодежи
# 20        ощущаю       ощушаю     оглушающие
# 21         молчу        молчю       молчанию
# 22        барьер       баръер       турбъерн
# 23           как       каааак      карамалак
# 24      письмена      писмена       писанием
# 25      самой-то      самойто          самой
# 26           тут          тул           тула
# 27        вообще         ваще           ваще
# 28        только         тока           тока
# 29      наверное     навернео        наверно
# ..           ...          ...            ...
# 506   совершенно   севершенно      свершенно
# 507       говорю          грю          герою
# 508       ничего         ничо           ночи
# 509        когда        погда         погода
# 510       как-то        както          каток
# 511     хотеться      хотеццо           отец
# 512     нравится     нравиццо          ницца
# 513          как        кааак         казака
# 514          как       каааак      карамалак
# 515          вот       воооот   водооборотов
# 516       кстати       кстате        остатке
# 517        очень         очен            чен
# 518       сильно       вильно         вольно
# 519        влево        влева        валеева
# 520       покажи   покажиииии        пожитки
# 521   девчонками   девочнками      девочками
# 522     придется    придеться      предаться
# 523        здесь        сдесь         садись
# 524   собственно       собсно           снбо
# 525       как-то       какето          катке
# 526     изюминку     изуминку          зинку
# 527        опять        апять           пять
# 528          мне         мной           мной
# 529         свои         сваи           васи
# 530    описывать    аписывать     записывать
# 531         чтоб          шоб         ошибок
# 532       ничего         ничо           ночи
# 533        жизнь        жизни          жизни
# 534   неожиданно  неожиданнго   неожиданного
# 535   собственно      собссно       способно
#
# [536 rows x 3 columns]

# %%
# Качество улучшилось, но, как ни странно, вектора у "не давнего" и "недавнего" довольно сильно отличаются, возможно, из-за разных контекстов: "не давнего, а ..." и "недавного времени/..."
get_closest_match_vec('не давнего', X, vec, 20).index('недавнего')
# Out:
# 17

# %% [markdown]
# ### Попробуем ещё улучшить качество, рассматривая не односимволные n-граммы, а, допустим, от 1-грамм до 3-грамм, чтобы получить чуть лучшее векторное представление слова, соответственно, слова, соответствующие близким словам, должны стать ещё ближе, а также, собственно, учитывать контекст в слове (до последовательностей из 3 букв).

# %%
vocab = list(WORDS.keys()) + [words[0] for i in range(len(true)) for words in align_words(true[i], bad[i])]
id2word = {i:word for i, word in enumerate(vocab)}

vec = TfidfVectorizer(analyzer='char', ngram_range=(1, 3))
X = vec.fit_transform(vocab)

# %%
correct = 0
total = 0

incorrect = [] # сюда будем сохранять ошибки

for i in range(len(true)):
    for pair in align_words(true[i], bad[i]):
        predicted = get_closest_hybrid_match(pair[1], X, vec)
        if predicted == pair[0]:
            correct += 1
        else:
            incorrect.append((pair[0], pair[1], predicted))
        total += 1
    if not i % 10:
        print(i)
        print(correct / total)
# Out:
# 0
# 1.0
# 10
# 0.9534883720930233
# 20
# 0.9434782608695652
# 30
# 0.9392405063291139
# 40
# 0.939453125
# 50
# 0.9419354838709677
# 60
# 0.9415855354659249
# 70
# 0.9417596034696406
# 80
# 0.9446808510638298
# 90
# 0.9419862340216323
# 100
# 0.9390134529147982
# 110
# 0.9394957983193277
# 120
# 0.9410852713178295
# 130
# 0.9412628487518355
# 140
# 0.9417808219178082
# 150
# 0.9422222222222222
# 160
# 0.9421145894861194
# 170
# 0.9409448818897638
# 180
# 0.9421841541755889
# 190
# 0.9442771084337349
# 200
# 0.944578313253012
# 210
# 0.945
# 220
# 0.9450643776824035
# 230
# 0.9457013574660633
# 240
# 0.9473480449090205
# 250
# 0.9485104817947775
# 260
# 0.9489256780556534
# 270
# 0.9485443466486121
# 280
# 0.9492566257272139
# 290
# 0.9489096573208723
# 300
# 0.9494432741498646
# 310
# 0.949177438307873
# 320
# 0.9491621698381142
# 330
# 0.9482710926694329
# 340
# 0.9479082321187584
# 350
# 0.9470372312532774
# 360
# 0.947956334094948
# 370
# 0.9485586481113321
# 380
# 0.9480425326244563
# 390
# 0.9482799525504152
# 400
# 0.9484200743494424
# 410
# 0.9482953262587491
# 420
# 0.9483255710800621
# 430
# 0.9486847779215178
# 440
# 0.9485278542681636
# 450
# 0.9482470784641068
# 460
# 0.9482653682288497
# 470
# 0.9484638255698712
# 480
# 0.949126213592233
# 490
# 0.9495256166982923
# 500
# 0.9503255813953488
# 510
# 0.9506352087114338
# 520
# 0.9506349490252191
# 530
# 0.9504671249779658
# 540
# 0.9510091426599966
# 550
# 0.9508670520231214
# 560
# 0.9500501169395256
# 570
# 0.9505063704671676
# 580
# 0.9510869565217391
# 590
# 0.9510664993726474
# 600
# 0.9508880308880309
# 610
# 0.9504606554901073
# 620
# 0.95099925980755
# 630
# 0.9513332361940843
# 640
# 0.951387890119373
# 650
# 0.9515443468404647
# 660
# 0.951216102879508
# 670
# 0.9506615214994487
# 680
# 0.9502372881355933
# 690
# 0.9501266835578077
# 700
# 0.9499145523859603
# 710
# 0.9496103896103896
# 720
# 0.949402850905355
# 730
# 0.949404007101192
# 740
# 0.94925
# 750
# 0.9493110236220472
# 760
# 0.9494888023369036
# 770
# 0.9496151996151996
# 780
# 0.9493821292775665
# 790
# 0.9495316159250585
# 800
# 0.9494972841788974
# 810
# 0.9492977046933881
# 820
# 0.9495779403489026
# 830
# 0.949744273960418
# 840
# 0.9495558723544248
# 850
# 0.9499460625674218
# 860
# 0.950143815915628
# 870
# 0.9499736703528173
# 880
# 0.9498540450375312
# 890
# 0.9498971193415637
# 900
# 0.9497507883226528
# 910
# 0.9494206549118388

# %%
# качество выросло на 3 сотых и почти достигло 0.95
print(correct / total)
# Out:
# 0.9496748374187094

# %%
# довольно естественные ошибки, хотя кое-где и довольно некорректно.
labels = "correct_word false_word predicted_word".split()
df = pd.DataFrame.from_records(incorrect, columns=labels)
df
# Out:
#     correct_word   false_word predicted_word
# 0        поясним       пояним        стояния
# 1      получатся     полчатся      ополчатся
# 2         насчет       нащщот       нащокина
# 3       основная      основая         основа
# 4        в общем       вобщем          общем
# 5          ящика        ящека          щекам
# 6         хорошо       хороше        хорошем
# 7         потому       патаму          датам
# 8            что          шта           штат
# 9         что-то        чтото           тото
# 10        мощный       мошный       тамошний
# 11        хорошо       хороше        хорошем
# 12      молодежь      молодеж       молодежи
# 13       сегодня        седня        средняя
# 14      навешать       вешать         вешать
# 15       конечно      канешна         внешне
# 16     начальник    начальнег     начального
# 17         зажег        зажог           ожог
# 18       женщина      женшина           шина
# 19      какие-то      какието          какие
# 20      молодежь      молодеж       молодежи
# 21        ощущаю       ощушаю         слушаю
# 22         молчу        молчю          молча
# 23        барьер       баръер           баре
# 24           как       каааак          саааа
# 25      письмена      писмена          смена
# 26      самой-то      самойто          самой
# 27           тут          тул           стул
# 28        вообще         ваще           ваще
# 29        только         тока           тока
# ..           ...          ...            ...
# 473       говорю          грю             гр
# 474       ничего         ничо        новичок
# 475       как-то        както          актов
# 476     хотеться      хотеццо           отец
# 477       погода        погда          когда
# 478          как        кааак            ааа
# 479          как       каааак          саааа
# 480  неискреннее  неискренное    неискренние
# 481          вот       воооот        мноооой
# 482     съездила     съездела         съезде
# 483        очень         очен          точен
# 484      центром       центрм          центр
# 485       сильно       вильно           виль
# 486     расскажу    рассказжу       рассказу
# 487   девчонками   девочнками      девочками
# 488     придется    придеться       видеться
# 489    некоторым   некотороым      некотором
# 490     действие     дейстиве        действо
# 491        самые        саиые           саид
# 492       как-то       какето        макетов
# 493     изюминку     изуминку          зинку
# 494        опять        апять           пять
# 495          мне         мной           мной
# 496         свои         сваи       осваивал
# 497    описывать    аписывать     записывать
# 498         чтоб          шоб             шо
# 499       ничего         ничо        новичок
# 500    некоторые     неоторые        которые
# 501        жизнь        жизни          жизни
# 502   неожиданно  неожиданнго   неожиданного
#
# [503 rows x 3 columns]

# %% [markdown]
# ### Не вижу смысла добавлять mystem, чтобы исправление было такой же частью речи, поскольку тогда мы будем ориентироваться на работу mystem по определению части речи для несуществующего/некорректного слова, а если предполагалось, что мы будем ориентироваться на правильные ответы, то будет странно, если мы будем пользоваться ответом в определении части речи. Также не вижу смысла ограничивать слова на вхождение в словарь по количеству встреч, т.к., как мы видели ранее, малое количество наоборот ухудшает качество, т.к. редкие слова в итоге превращаются в абсолютно другое, хотя должны были бы оставаться без изменений.

# %% [markdown]
# В рассмотренных методах при выборе исправления никак не использовался контекст. Про то как это можно сделать, можно почитать вот тут - https://habr.com/ru/post/346618/
